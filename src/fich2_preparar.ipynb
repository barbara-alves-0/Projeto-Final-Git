# %%
import sqlite3
from pathlib import Path
import pandas as pd

df = pd.read_csv("../data/raw/morbilidade_mortalidade_hospit_fich2.csv",
                  sep=";", encoding="utf-8-sig")

df.columns = ["periodo", "regiao", "instituicao", "codigo_diagnostico_principal", "descricao_diagnostico_principal", "faixa_etaria", "sexo", "internamentos", "dias_internamentos", "ambulatorio", "obitos"]


print(df.shape)                 # (linhas, colunas)
display(df.head())              # primeiras 5 linhas
display(df.info())              # colunas, tipos e não nulos           
display(df.describe().round(2)) # estatísticas das colunas numéricas arredondado para 2 casas decimais
# Out:
# (524406, 11)
#    periodo                       regiao  \
# 0  2026-03     Região de Saúde do Norte
# 1  2026-03   Região de Saúde do Algarve
# 2  2026-03  Região de Saúde do Alentejo
# 3  2026-03     Região de Saúde do Norte
# 4  2026-03     Região de Saúde do Norte
#
#                                        instituicao  \
# 0          Unidade Local de Saúde de Braga, E.P.E.
# 1        Unidade Local de Saúde do Algarve, E.P.E.
# 2  Unidade Local de Saúde do Alto Alentejo, E.P.E.
# 3     Unidade Local de Saúde do Alto Minho, E.P.E.
# 4     Unidade Local de Saúde do Alto Minho, E.P.E.
#
#    codigo_diagnostico_principal  \
# 0                            12
# 1                            13
# 2                            13
# 3                            13
# 4                            13
#
#                      descricao_diagnostico_principal faixa_etaria sexo  \
# 0             Doenças da pele e do tecido subcutâneo     [65-120[    M
# 1  Doenças do aparelho osteomuscular e do tecido ...      [45-65[    M
# 2  Doenças do aparelho osteomuscular e do tecido ...      [45-65[    F
# 3  Doenças do aparelho osteomuscular e do tecido ...      [45-65[    F
# 4  Doenças do aparelho osteomuscular e do tecido ...     [65-120[    M
#
#    internamentos  dias_internamentos  ambulatorio  obitos
# 0              2                  24            0       0
# 1              2                   3            1       0
# 2              4                  32            3       0
# 3              1                   2            8       0
# 4              0                   0            6       0
# <class 'pandas.DataFrame'>
# RangeIndex: 524406 entries, 0 to 524405
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   periodo                          524406 non-null  str
#  1   regiao                           524406 non-null  str
#  2   instituicao                      524406 non-null  str
#  3   codigo_diagnostico_principal     524406 non-null  int64
#  4   descricao_diagnostico_principal  524406 non-null  str
#  5   faixa_etaria                     524406 non-null  str
#  6   sexo                             524406 non-null  str
#  7   internamentos                    524406 non-null  int64
#  8   dias_internamentos               524406 non-null  int64
#  9   ambulatorio                      524406 non-null  int64
#  10  obitos                           524406 non-null  int64
# dtypes: int64(5), str(6)
# memory usage: 44.0 MB
# None
#        codigo_diagnostico_principal  internamentos  dias_internamentos  \
# count                     524406.00      524406.00           524406.00
# mean                          10.81          10.25               85.80
# std                            6.09          22.82              201.77
# min                            1.00           0.00                0.00
# 25%                            6.00           1.00                3.00
# 50%                           11.00           3.00               15.00
# 75%                           15.00           8.00               71.00
# max                           22.00         470.00            14830.00
#
#        ambulatorio     obitos
# count    524406.00  524406.00
# mean         12.43       0.69
# std          50.23       2.43
# min           0.00       0.00
# 25%           0.00       0.00
# 50%           1.00       0.00
# 75%           5.00       0.00
# max        1267.00     120.00
