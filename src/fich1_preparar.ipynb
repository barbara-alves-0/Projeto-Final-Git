# %%
import sqlite3
from pathlib import Path
import pandas as pd

df = pd.read_csv("../data/raw/atividade-de-internamento-hospitalar_fich1.csv",
                  sep=";", encoding="utf-8-sig")

print(df.shape)          # (linhas, colunas)
print(df.columns)        # nomes das colunas
print(df.head())         # primeiras 5 linhas
print(df.dtypes)         # tipo de cada coluna (texto, número, etc.)
print(df.isna().sum())   # quantos valores em falta por coluna
print(df.describe())     # estatísticas básicas das colunas numéricas
# Out:
# (17616, 7)
# Index(['Período', 'Região', 'Instituição', 'Localização Geográfica',
#        'Tipo de Especialidade', 'Doentes Saídos', 'Dias de Internamento'],
#       dtype='str')
#    Período                 Região  \
# 0  2015-05    Região de Saúde LVT
# 1  2015-05  Região de Saúde Norte
# 2  2015-05  Região de Saúde Norte
# 3  2015-05  Região de Saúde Norte
# 4  2015-05  Região de Saúde Norte
#
#                                          Instituição  Localização Geográfica  \
# 0         Centro Hospitalar de Lisboa Ocidental, EPE    38.708454, -9.216985
# 1  Centro Hospitalar Trás-os-Montes e Alto Douro,...  41.3031784, -7.7515252
# 2    Hospital da Senhora da Oliveira, Guimarães, EPE  41.4387173, -8.3086907
# 3                             Hospital de Braga, PPP     41.56785, -8.398982
# 4          Unidade Local de Saúde de Matosinhos, EPE  41.1794456, -8.6745115
#
#   Tipo de Especialidade  Doentes Saídos  Dias de Internamento
# 0          Outras Camas           329.0                8327.0
# 1          Outras Camas           150.0                2392.0
# 2          Outras Camas           116.0                2066.0
# 3          Outras Camas            71.0                1470.0
# 4          Outras Camas            49.0                 802.0
# Período                       str
# Região                        str
# Instituição                   str
# Localização Geográfica        str
# Tipo de Especialidade         str
# Doentes Saídos            float64
# Dias de Internamento      float64
# dtype: object
# Período                    0
# Região                     0
# Instituição                0
# Localização Geográfica     0
# Tipo de Especialidade      0
# Doentes Saídos            28
# Dias de Internamento      33
# dtype: int64
#        Doentes Saídos  Dias de Internamento
# count    17588.000000          17583.000000
# mean      3157.159939          27088.150600
# std       3942.833056          32915.378876
# min          0.000000             37.000000
# 25%        420.750000           4929.000000
# 50%       1710.000000          15470.000000
# 75%       4473.250000          36047.500000
# max      34354.000000         259313.000000
